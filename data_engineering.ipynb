# %%
import pandas as pd
import os
import urllib.request
import socket

socket.setdefaulttimeout(20)


CSV_PATH = "./en.openfoodfacts.org.products.csv"
IMAGES_PATH = "./data/images/"
LABEL_PATH = "./data/labels.csv"

# %%
df = pd.read_csv(CSV_PATH, "\t")
# Out:
# C:\Users\babal\Miniconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\babal\Miniconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0,8,14,20,21,22,23,24,28,29,30,32,33,42,43,44,49,63) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#                    code                                                url  \
# 0     00000000000000225  http://world-en.openfoodfacts.org/product/0000...
# 1  00000000000003429145  http://world-en.openfoodfacts.org/product/0000...
# 2         0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 3         0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 4    000000000003327986  http://world-en.openfoodfacts.org/product/0000...
#
#           creator   created_t      created_datetime  last_modified_t  \
# 0  nutrinet-sante  1623855208  2021-06-16T14:53:28Z       1623855209
# 1         kiliweb  1630483911  2021-09-01T08:11:51Z       1630484064
# 2         kiliweb  1529059080  2018-06-15T10:38:00Z       1561463718
# 3        isagoofy  1539464774  2018-10-13T21:06:14Z       1539464817
# 4         kiliweb  1574175736  2019-11-19T15:02:16Z       1624390765
#
#   last_modified_datetime               product_name abbreviated_product_name  \
# 0   2021-06-16T14:53:29Z             jeunes pousses                      NaN
# 1   2021-09-01T08:14:24Z                    L.casei                      NaN
# 2   2019-06-25T11:55:18Z           Vitória crackers                      NaN
# 3   2018-10-13T21:06:57Z                      Cacao                      NaN
# 4   2021-06-22T19:39:25Z  Filetes de pollo empanado                      NaN
#
#   generic_name  ... carbon-footprint-from-meat-or-fish_100g  \
# 0          NaN  ...                                     NaN
# 1          NaN  ...                                     NaN
# 2          NaN  ...                                     NaN
# 3          NaN  ...                                     NaN
# 4          NaN  ...                                     NaN
#
#   nutrition-score-fr_100g nutrition-score-uk_100g glycemic-index_100g  \
# 0                     NaN                     NaN                 NaN
# 1                     NaN                     NaN                 NaN
# 2                     NaN                     NaN                 NaN
# 3                     NaN                     NaN                 NaN
# 4                     NaN                     NaN                 NaN
#
#   water-hardness_100g choline_100g phylloquinone_100g beta-glucan_100g  \
# 0                 NaN          NaN                NaN              NaN
# 1                 NaN          NaN                NaN              NaN
# 2                 NaN          NaN                NaN              NaN
# 3                 NaN          NaN                NaN              NaN
# 4                 NaN          NaN                NaN              NaN
#
#   inositol_100g carnitine_100g
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
#
# [5 rows x 186 columns]

# %%
df
# Out:
#                          code  \
# 0           00000000000000225
# 1        00000000000003429145
# 2               0000000000017
# 3               0000000000031
# 4          000000000003327986
# ...                       ...
# 2219529         9999999910128
# 2219530             999999999
# 2219531         9999999990397
# 2219532         9999999999994
# 2219533       999999999999999
#
#                                                        url  \
# 0        http://world-en.openfoodfacts.org/product/0000...
# 1        http://world-en.openfoodfacts.org/product/0000...
# 2        http://world-en.openfoodfacts.org/product/0000...
# 3        http://world-en.openfoodfacts.org/product/0000...
# 4        http://world-en.openfoodfacts.org/product/0000...
# ...                                                    ...
# 2219529  http://world-en.openfoodfacts.org/product/9999...
# 2219530  http://world-en.openfoodfacts.org/product/9999...
# 2219531  http://world-en.openfoodfacts.org/product/9999...
# 2219532  http://world-en.openfoodfacts.org/product/9999...
# 2219533  http://world-en.openfoodfacts.org/product/9999...
#
#                             creator   created_t      created_datetime  \
# 0                    nutrinet-sante  1623855208  2021-06-16T14:53:28Z
# 1                           kiliweb  1630483911  2021-09-01T08:11:51Z
# 2                           kiliweb  1529059080  2018-06-15T10:38:00Z
# 3                          isagoofy  1539464774  2018-10-13T21:06:14Z
# 4                           kiliweb  1574175736  2019-11-19T15:02:16Z
# ...                             ...         ...                   ...
# 2219529                     kiliweb  1572513866  2019-10-31T09:24:26Z
# 2219530              nutrinet-sante  1608105503  2020-12-16T07:58:23Z
# 2219531                     kiliweb  1581171613  2020-02-08T14:20:13Z
# 2219532                     kiliweb  1613129728  2021-02-12T11:35:28Z
# 2219533  openfoodfacts-contributors  1587222660  2020-04-18T15:11:00Z
#
#          last_modified_t last_modified_datetime  \
# 0             1623855209   2021-06-16T14:53:29Z
# 1             1630484064   2021-09-01T08:14:24Z
# 2             1561463718   2019-06-25T11:55:18Z
# 3             1539464817   2018-10-13T21:06:57Z
# 4             1624390765   2021-06-22T19:39:25Z
# ...                  ...                    ...
# 2219529       1572513866   2019-10-31T09:24:26Z
# 2219530       1608105504   2020-12-16T07:58:24Z
# 2219531       1582644247   2020-02-25T15:24:07Z
# 2219532       1645464702   2022-02-21T17:31:42Z
# 2219533       1605558295   2020-11-16T20:24:55Z
#
#                                    product_name abbreviated_product_name  \
# 0                                jeunes pousses                      NaN
# 1                                       L.casei                      NaN
# 2                              Vitória crackers                      NaN
# 3                                         Cacao                      NaN
# 4                     Filetes de pollo empanado                      NaN
# ...                                         ...                      ...
# 2219529  Sandwich club Rillette poisson combava                      NaN
# 2219530                 Thé noir BIO Darjeeling                      NaN
# 2219531                                    Fati                      NaN
# 2219532               Light & Free SKYR A BOIRE                      NaN
# 2219533                       Signal Toothpaste                      NaN
#
#         generic_name  ... carbon-footprint-from-meat-or-fish_100g  \
# 0                NaN  ...                                     NaN
# 1                NaN  ...                                     NaN
# 2                NaN  ...                                     NaN
# 3                NaN  ...                                     NaN
# 4                NaN  ...                                     NaN
# ...              ...  ...                                     ...
# 2219529          NaN  ...                                     NaN
# 2219530          NaN  ...                                     NaN
# 2219531          NaN  ...                                     NaN
# 2219532          NaN  ...                                     NaN
# 2219533          NaN  ...                                     NaN
#
#         nutrition-score-fr_100g nutrition-score-uk_100g glycemic-index_100g  \
# 0                           NaN                     NaN                 NaN
# 1                           NaN                     NaN                 NaN
# 2                           NaN                     NaN                 NaN
# 3                           NaN                     NaN                 NaN
# 4                           NaN                     NaN                 NaN
# ...                         ...                     ...                 ...
# 2219529                     NaN                     NaN                 NaN
# 2219530                     NaN                     NaN                 NaN
# 2219531                     NaN                     NaN                 NaN
# 2219532                    25.0                     NaN                 NaN
# 2219533                     NaN                     NaN                 NaN
#
#         water-hardness_100g choline_100g phylloquinone_100g beta-glucan_100g  \
# 0                       NaN          NaN                NaN              NaN
# 1                       NaN          NaN                NaN              NaN
# 2                       NaN          NaN                NaN              NaN
# 3                       NaN          NaN                NaN              NaN
# 4                       NaN          NaN                NaN              NaN
# ...                     ...          ...                ...              ...
# 2219529                 NaN          NaN                NaN              NaN
# 2219530                 NaN          NaN                NaN              NaN
# 2219531                 NaN          NaN                NaN              NaN
# 2219532                 NaN          NaN                NaN              NaN
# 2219533                 NaN          NaN                NaN              NaN
#
#         inositol_100g carnitine_100g
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 2219529           NaN            NaN
# 2219530           NaN            NaN
# 2219531           NaN            NaN
# 2219532           NaN            NaN
# 2219533           NaN            NaN
#
# [2219534 rows x 186 columns]

# %%
filter_df = df.dropna(how='any', subset=["categories_en", "image_url"])
filter_df[["categories_en", "image_url"]]
# Out:
#                                              categories_en  \
# 7                     Groceries,Condiments,Sauces,Mustards
# 16                                   Marzipan,Almond paste
# 17       Meals,Prepared vegetables,Grated carrots,Seaso...
# 26                            Pies,Sweet pies,Coconut pies
# 36       Plant-based foods and beverages,Plant-based fo...
# ...                                                    ...
# 2219525        Biscuits and cakes,Cakes,de:tiefkühl-kuchen
# 2219526  Meats,Beef,Steaks,Beef steaks,Ground steaks,Gr...
# 2219527  Plant-based foods and beverages,Plant-based fo...
# 2219532    Dairies,Fermented foods,Fermented milk products
# 2219533     Non food products,Open Beauty Facts,Toothpaste
#
#                                                  image_url
# 7        https://images.openfoodfacts.org/images/produc...
# 16       https://images.openfoodfacts.org/images/produc...
# 17       https://images.openfoodfacts.org/images/produc...
# 26       https://images.openfoodfacts.org/images/produc...
# 36       https://images.openfoodfacts.org/images/produc...
# ...                                                    ...
# 2219525  https://images.openfoodfacts.org/images/produc...
# 2219526  https://images.openfoodfacts.org/images/produc...
# 2219527  https://images.openfoodfacts.org/images/produc...
# 2219532  https://images.openfoodfacts.org/images/produc...
# 2219533  https://images.openfoodfacts.org/images/produc...
#
# [704651 rows x 2 columns]

# %%
filtered_categories = ["Beverages", "Sweet snacks", "Dairies", "Cereals and potatoes", "Meats", "Fermented foods", "Fermented milk products", 
                    "Groceries", "Meals", "Cereals and their products", "Cheeses", "Sauces", "Spreads", "Confectioneries", "Prepared meats", 
                    "Frozen foods", "Breakfasts", "Desserts", "Canned foods", "Seafood", "Cocoa and its products", "Fats", "Condiments", 
                    "Fishes", "Breads", "Yogurts", "Cakes", "Biscuits", "Pastas", "Legumes"]
filtered_categories = [s.lower() for s in filtered_categories]
print(len(filtered_categories))

CLASS_TO_INDEX = {filtered_categories[i]:i for i in range(len(filtered_categories))}
INDEX_TO_CLASS = {i:filtered_categories[i] for i in range(len(filtered_categories))}
# Out:
# 30

# %%
def idx_to_str(idx):
    tmp_idx = idx
    zeros = 7
    while tmp_idx // 10 > 0:
        tmp_idx = tmp_idx // 10
        zeros -= 1
    return "0"*zeros + str(idx)

def filter_categories(categories_str):
    s = categories_str.lower().split(',')
    out = ""
    for label in CLASS_TO_INDEX:
        if label in s:
            out += str(CLASS_TO_INDEX[label]) + ","
            continue
    if len(out) == 0: return out
    return out[:-1] # Remove last coma

# %%
filter_df.reset_index()
true_idx = 0

label_df = pd.DataFrame(columns=["file", "labels"])

for idx, row in filter_df[["categories_en", "image_url"]].iterrows():
    try:
            labels = filter_categories(row["categories_en"])
            if labels == "":
                continue

            name = idx_to_str(true_idx) + ".jpg"
            url = row["image_url"]

            urllib.request.urlretrieve(url, os.path.join(IMAGES_PATH, name))

            label_df.loc[true_idx] = {"file": name, "labels":labels}


            true_idx += 1
    except Exception as e:
        print("An error occured, skipping row " + str(idx))
        print(e)    

    if true_idx % 500 == 0: 
        print(idx)

    if true_idx % 5000 == 0:
        label_df.to_csv(LABEL_PATH)
# Out:
# 2957
# 6944
# 13145
# 22230
# 25483
# 30851
# 33113
# 37032
# 42912
# 48677
# 52908
# 56980
# 60832
